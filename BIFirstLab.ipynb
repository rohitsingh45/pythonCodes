# %% [markdown]
# <a href="https://colab.research.google.com/github/rohitsingh45/pythonCodes/blob/master/BIFirstLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
height = np.arange(150,200,2)
height

# %%
plt.hist(height,rwidth=.9)

# %%
plt.hist(height,rwidth=.9,bins=4)
# Out:
# (array([6., 6., 6., 7.]),
#  array([150., 162., 174., 186., 198.]),
#  <BarContainer object of 4 artists>)

# %%
bin = [150,170,180,195]
plt.hist(height,rwidth=.9, bins=bin)

# %%
height_m = np.arange(150,200,2)
height_f = np.arange(140,180,2)
bin = [150,165,175,190]
plt.hist([height_m,height_f],rwidth=.9)
plt.legend()
plt.hist([height_m,height_f],rwidth=.9, label=['m','f'])
plt.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
